# %% [markdown]
# **Instalation:-**

# %%
! pip install min_dalle -q
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.4/431.4 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 23.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Importing MinDalle

# %%
from min_dalle import MinDalle

model = MinDalle(is_mega=True, is_reusable=True)
# Out:
# using device cuda
# downloading tokenizer params
# intializing TextTokenizer
# downloading encoder params
# initializing DalleBartEncoder
# downloading decoder params
# initializing DalleBartDecoder
# downloading detokenizer params
# initializing VQGanDetokenizer

# %% [markdown]
# # **Giving text input**

# %%
# %%time

text = "realistic white cat potrate with a ball ,playing "
seed = 6
grid_size = 2

display(model.generate_image(text, seed , grid_size))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
# CPU times: user 33.4 s, sys: 423 ms, total: 33.8 s
# Wall time: 35.3 s
